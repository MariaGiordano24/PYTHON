# %%
#TASK 1
1. Aprire l’app Note. 
2. Scrivere i prodotti da comprare.
3. Prendere le chiavi dell’auto.
4. Arrivare al supermercato.
5. Prendere il carrello.
6. Prendere i prodotti elencati. 
7. Pagare alla cassa.
8. Mettere le buste in macchina.
9. Tornare a casa. 
10. Portare le buste in casa. 
11. Mettere la spesa a posto.

# %%
Studenti = 25
print(Studenti)

Studenti = 25
Aggiunta_Studenti = 3
print(Studenti + Aggiunta_Studenti)
# Out:
# 25
# 28

# %%
Scuola = "Epicode"
print(Scuola)
# Out:
# Epicode

# %%
X = 10
X = X + 2 
X= X * 3
print(X)
# Out:
# 36

# %%
str1 = "Windows"
print(len(str1))
str2 = "Excel"
print(len(str2))
str3 = "Powerpoint"
print(len(str3))
str4 = "Word"
print(len(str4))
# Out:
# 7
# 5
# 10
# 4

# %%
Secondi_in_minuto = 60
Minuti_in_ora = 60
Ore_in_giorno = 24
Giorni_in_anno = 365

Secondi_in_anno = Secondi_in_minuto * Minuti_in_ora * Ore_in_giorno * Giorni_in_anno

print(Secondi_in_anno)
# Out:
# 31536000

# %%
my_string = "I am studying Python"
print(my_string)

my_string_maiusc = my_string.upper()    #STRINGA IN MAIUSCOLO. 
print(my_string_maiusc)

print(my_string.lower())                #STRINGA IN MINUSCOLO.

cambio_parola = my_string.replace("Python", "a lot")     #SOSTITUIRE PYTHON CON A LOT.
print(cambio_parola)

my_string = "I am studying Python"                      #RESTITUISCE UNA COPIA DELLA STRINGA SENZA SPAZI VUOTI ALL'INIZIO E ALLA FINE.
print(my_string.strip())

parole = my_string.split(" ")                      #DIVIDE LA STRINGA IN BASE AD UN DELIMITATORE.
print(parole)
# Out:
# I am studying Python
# I AM STUDYING PYTHON
# i am studying python
# I am studying a lot
# I am studying Python
# ['I', 'am', 'studying', 'Python']

# %%
#Abbiamo due liste, una di studenti e una di corsi: studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
#corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]
#Esercizio (2/2) Tenendo conto che i dati sono in corrispondenza posizionale, leggiamo con attenzione le due liste. 
#Sapendo che Emma segue Data Analyst Faith segue Backend Grace segue Frontend Henry segue Cybersecurity alla lista cui mancano dei dati,
#ggiungiamo i dati mancanti uno alla volta con il metodo .append()

# LISTE INIZIALI.
studenti = ["Alex", "Bob", "Cindy", "Dan", "Emma", "Faith", "Grace", "Henry"]
corsi = ["Cybersecurity", "Data Analyst", "Backend", "Frontend", "Data Analyst", "Backend"]

# AGGIUNGIAMO I CORSI MANCANTI.
corsi.append("Frontend")               # PER GRACE
corsi.append("Cybersecurity")          # PER HENRY
print(studenti)
print(corsi)
# Out:
# ['Alex', 'Bob', 'Cindy', 'Dan', 'Emma', 'Faith', 'Grace', 'Henry']
# ['Cybersecurity', 'Data Analyst', 'Backend', 'Frontend', 'Data Analyst', 'Backend', 'Frontend', 'Cybersecurity']
